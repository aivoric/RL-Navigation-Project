# %%
import os
from matplotlib import pyplot as plt
import pickle
import numpy as np

# %%
result_files = os.listdir("results")
print(result_files)
# Out:
# ['1609345659.pickle', '1609339606.pickle', '1609339283.pickle', '1609339149.pickle']

# %%
for file in result_files:
    print("\n#################\nANALYSING RESULTS FOR: {}\n#################".format(file))
    
    file_location = os.path.join('results', file)
    
    with open(file_location, 'rb') as handle:
        saved_results = pickle.load(handle)
        
    print("\nFINAL SCORE: {}\n".format(saved_results['final_score']))
    
    scores = saved_results['all_scores']
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(np.arange(len(scores)), scores)
    plt.ylabel('Score')
    plt.xlabel('Episode #')
    plt.show()
# Out:
# #################
# ANALYSING RESULTS FOR: 1609345659.pickle
# #################
#
# FINAL SCORE: 1.22
# #################
# ANALYSING RESULTS FOR: 1609339606.pickle
# #################
#
# FINAL SCORE: -0.03333333333333333
# #################
# ANALYSING RESULTS FOR: 1609339283.pickle
# #################
#
# FINAL SCORE: -0.06666666666666667
# #################
# ANALYSING RESULTS FOR: 1609339149.pickle
# #################
#
# FINAL SCORE: 0.0
