# %%
import os
from matplotlib import pyplot as plt
import pickle
import numpy as np

# %%
result_files = os.listdir("results")
print(result_files)
# Out:
# ['1609440064_Third Experiment.pickle', '1609440043_Benchmark.pickle', '1609438463_Benchmark.pickle', '1609438681_Benchmark.pickle', '1609439895_Second Experiment.pickle', '1609439832_Benchmark.pickle', '1609438993_Benchmark.pickle']

# %%
for file in result_files:
    print("\n#################\nANALYSING RESULTS FOR: {}\n#################".format(file))
    
    file_location = os.path.join('results', file)
    
    with open(file_location, 'rb') as handle:
        saved_results = pickle.load(handle)
        
    print("\nFINAL SCORE: {}\n".format(saved_results['final_score']))
    
    scores = saved_results['all_scores']
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(np.arange(len(scores)), scores)
    plt.ylabel('Score')
    plt.xlabel('Episode #')
    plt.show()
# Out:
# #################
# ANALYSING RESULTS FOR: 1609440064_Third Experiment.pickle
# #################
#
# FINAL SCORE: 0.4
# #################
# ANALYSING RESULTS FOR: 1609440043_Benchmark.pickle
# #################
#
# FINAL SCORE: 0.5
# #################
# ANALYSING RESULTS FOR: 1609438463_Benchmark.pickle
# #################
#
# FINAL SCORE: 0.13333333333333333
# #################
# ANALYSING RESULTS FOR: 1609438681_Benchmark.pickle
# #################
#
# FINAL SCORE: -0.13333333333333333
# #################
# ANALYSING RESULTS FOR: 1609439895_Second Experiment.pickle
# #################
#
# FINAL SCORE: 0.03333333333333333
# #################
# ANALYSING RESULTS FOR: 1609439832_Benchmark.pickle
# #################
#
# FINAL SCORE: 0.26666666666666666
# #################
# ANALYSING RESULTS FOR: 1609438993_Benchmark.pickle
# #################
#
# FINAL SCORE: 0.13333333333333333
